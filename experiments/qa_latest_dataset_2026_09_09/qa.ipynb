# %% [markdown]
# # QA the latest flipped stimulus dataset
#
# Load the pinned flips parquet from `experiments/generate_flips_2026_09_08` (10182 rows). Keep ID, original text, mirror text, political lean, and toxicity tier, then print the head of that table.
#
# From the repository root:
#
# ```bash
# uv sync --extra jupyter
# uv run --extra jupyter jupyter lab
# ```

# %%
import pandas as pd

pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_rows", 50)

# %%
from experiments.qa_latest_dataset_2026_09_09.load import load_flips_dataset, qa_table

flips = load_flips_dataset()
df = qa_table(flips)
print(f"rows={len(df)}")
#print(df.head())
df.head(500).style.set_properties(
    subset=["original text", "mirror text"],
    **{
        "text-align": "left",
        "white-space": "pre-wrap",
        "vertical-align": "top",
    },
)
# Out:
# rows=10182
# <style type="text/css">
# ...
